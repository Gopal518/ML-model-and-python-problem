# %%
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
# Load dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv"

# %%
names = []
flwr_data = pd.read_csv(url)
print(flwr_data.shape)
# Out:
# (149, 5)

# %%
print(flwr_data.head())
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
flwr_data.columns=['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
print(flwr_data.head())
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# # class distribution
# print(dataset.groupby('class').size())

# %%
scatter_matrix(flwr_data)
plt.show()

# %%
np.random.shuffle(flwr_data.values)
X = flwr_data.drop("class", axis = 1)
Y = flwr_data['class']
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=.20)

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, Y_train)
predictions = knn.predict(X_validation)
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# [[13  0  0]
#  [ 0  9  1]
#  [ 0  0  7]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      0.90      0.95        10
#  Iris-virginica       0.88      1.00      0.93         7
#
#       micro avg       0.97      0.97      0.97        30
#       macro avg       0.96      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
log_reg = LogisticRegression(multi_class = 'auto' , solver = 'lbfgs', max_iter = 3)
log_reg.fit(X_train, Y_train)
predictions = log_reg.predict(X_validation)
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# [[13  0  0]
#  [ 0 10  0]
#  [ 0  7  0]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.59      1.00      0.74        10
#  Iris-virginica       0.00      0.00      0.00         7
#
#       micro avg       0.77      0.77      0.77        30
#       macro avg       0.53      0.67      0.58        30
#    weighted avg       0.63      0.77      0.68        30
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
svm = SVC(gamma='auto')
svm.fit(X_train, Y_train)
predictions = svm.predict(X_validation)
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# [[13  0  0]
#  [ 0 10  0]
#  [ 0  0  7]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      1.00      1.00        10
#  Iris-virginica       1.00      1.00      1.00         7
#
#       micro avg       1.00      1.00      1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
